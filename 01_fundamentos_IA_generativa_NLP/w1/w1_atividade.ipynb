# %% [markdown]
# # **BLOCO 1**
# # Modelos de Aprendizado de Máquina e Redes Neurais (Aula Prática)
#
# Nesta aula vamos treinar **quatro modelos de Machine Learning**.
# A ideia é sempre seguir o **mesmo padrão**:
#
# 1. Carregar o dataset
# 2. Criar o modelo
# 3. Treinar o modelo (`fit`)
# 4. Fazer previsões (`predict`)
# 5. Visualizar os resultados
#
# Modelos da aula:
#
# - Regressão Linear
# - Regressão Logística
# - Árvore de Decisão
# - K-Means
#
# Experimente você mesmo (no final de cada modelo):
# - Alterações do código: clicar na área de edição e alterar
#
# Exercício com Redes Neurais (ex: MLP,CNN):
# - Construir modelos de rede neurais para os problemas acima
#
# Exercícios desafios (avançados):
# - Incluir ajustes de hiperparâmetros (com validação cruzada) para redes neurais criadas
# - Incluir métricas e visualizações adicionais para cada modelo criado
# - Construir análise comparativa entre os modelos
#
# **As atividades práticas não são avaliativas, mas devem ser entregues da seguinte forma para obtenção de feedback pelo monitor da disciplina:**
# - Entregar arquivo ipynb ou link para notebook compartilhado para leitura
# - O notebook deve incluir os resultados da execução, bem como explicações sobre os passos realizados

# %% [markdown]
# # Importando bibliotecas
#
# Usaremos apenas algumas bibliotecas simples.

# %%
import pandas as pd # importando biblioteca pandas, ja fizemos isso na ultima aula!
import matplotlib.pyplot as plt # importando biblioteca matplotlib, já fizemos isso na ultima aula!

from sklearn.model_selection import train_test_split # novidade aqui, importando o train_test_split
from sklearn.metrics import accuracy_score # outra novidade, importando o accuracy!

# %% [markdown]
# # 1️⃣ Regressão Linear
#
# A regressão linear é usada para **prever números**.
#
# Exemplo: prever o **preço de casas**.
#
# Vamos usar o dataset **California Housing**. Esse dataset vem do censo da Califórnia de 1990 e cada linha representa uma pequena região dentro da California.

# %%
from sklearn.datasets import fetch_california_housing # vamos usar o dataset California Housing
from sklearn.linear_model import LinearRegression # vamos usar a regressão linear, que é um dos tipos de modelo de aprendizado de máquina

dataset_california_housing = fetch_california_housing(as_frame=True).frame # pega os dados (que não vem de um csv) e coloca em um dataframe pandas

# %%
# vamos entender melhor esses dados
dataset_california_housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# ### Explicação das colunas
#
# - **MedInc** ->	renda média das famílias da região
# - **HouseAge** ->	idade média das casas do bairro
# - **AveRooms** ->	número médio de cômodos por casa
# - **AveBedrms** ->	número médio de quartos de dormir
# - **Population** ->	população total da região censitária
# - **AveOccup** ->	média de moradores por residência
# - **Latitude** ->	coordenada geográfica norte-sul
# - **Longitude** ->	coordenada geográfica leste-oeste
# - **MedHouseValue** ->	valor médio das casas da região em centenas de milhares de dólares

# %%
colunas_house = dataset_california_housing[["MedInc"]]  # vamos tentar prever o preço (nosso alvo) usando só a coluna/feature MedInc
alvo_house = dataset_california_housing["MedHouseVal"]  # nosso alvo, o preço da casa

# %%
colunas_house.head()
# Out:
#    MedInc
# 0  8.3252
# 1  8.3014
# 2  7.2574
# 3  5.6431
# 4  3.8462

# %%
alvo_house.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
correlacao_pearson = colunas_house["MedInc"].corr(alvo_house, method ="pearson")

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].set_title(f"Correlação de Pearson: {correlacao_pearson:.5f}", fontsize=10, loc="left")
axs[0].scatter(colunas_house, alvo_house, alpha=0.5, label="Dados reais")
axs[0].set_xlabel("MedInc (Renda média das famílias)", fontsize=8)
axs[0].set_ylabel("MedHouseVal (Valor médio das casas)", fontsize=8)
axs[1].boxplot([colunas_house["MedInc"], alvo_house], tick_labels=["MedInc", "MedHouseVal"])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Por que separar em treino e teste?
#
# Imagine que você vai fazer uma prova amanhã.
# Você passa a noite estudando as questões **da própria prova**.
# No dia seguinte, acerta tudo — mas isso prova que você aprendeu ou só que memorizou?
#
# Com modelos de Machine Learning é a mesma coisa.
# Se treinarmos e avaliarmos o modelo nos **mesmos dados**, ele vai parecer ótimo
# porque "decorou" as respostas... e vai falhar miseravelmente em dados novos.
#
# Para evitar isso, dividimos os dados em dois grupos:
#
# - **Treino**: os dados que o modelo vai usar para aprender
# - **Teste**: dados que o modelo **nunca viu** durante o treino, usados apenas para avaliação
#
# O `train_test_split` faz essa divisão automaticamente, de forma aleatória.
#
# Uma divisão típica é **80% treino / 20% teste**, mas isso pode variar conforme o tamanho do dataset.

# %%
colunas_house_treino, colunas_house_teste, alvo_house_treino, alvo_house_teste = train_test_split(colunas_house, alvo_house, test_size=0.01, random_state=42) # divide em treino e teste. Teste só 1% do database

# %%
modelo_house = LinearRegression() # aqui estamos dizendo que queremos usar a Regressão Linear
modelo_house.fit(colunas_house_treino, alvo_house_treino) # a função fit é a que faz o treino, ou seja, momento que o modelo começa a aprender com os dados
pred = modelo_house.predict(colunas_house_teste) # com o modelo treinado, podemos predizer o valor das casas de teste

# %%
pred # valor das casas preditas de teste
# Out:
# array([1.15242845, 1.50808535, 1.90503543, 2.8495072 , 2.00749441,
#        2.42155585, 2.5760183 , 1.99318613, 2.458749  , 3.84338854,
#        1.5124364 , 1.70417568, 1.64535276, 1.84679824, 2.69437536,
#        2.04728146, 2.08334501, 2.17885903, 2.04862024, 1.36424951,
#        2.21864608, 2.27596286, 2.68642631, 3.0146381 , 2.21601034,
#        1.26915386, 1.51607623, 1.80876834, 1.97611661, 3.04413323,
#        1.12665682, 0.96365961, 1.88348934, 3.42401379, 1.9099722 ,
#        2.75265439, 2.27943534, 1.8763352 , 1.74254027, 1.59209418,
#        3.21336416, 2.03539973, 1.39788652, 1.89993131, 2.09476653,
#        1.71342167, 1.91737737, 1.74078311, 1.597533  , 1.79688662,
#        2.33173167, 1.53833355, 1.88348934, 1.11498428, 1.6154811 ,
#        2.72236435, 1.3020378 , 2.57262949, 2.37302485, 2.7736566 ,
#        2.21822771, 1.65367834, 1.55117753, 1.68262959, 3.06275072,
#        1.93503261, 1.59778402, 2.15463537, 0.9617351 , 1.48453108,
#        1.95360826, 2.45443978, 1.93080706, 2.16647526, 1.90072621,
#        2.03104867, 3.0038023 , 2.12953313, 2.16128746, 1.40269778,
#        1.4649095 , 1.49499035, 1.16096321, 1.16188363, 3.34146926,
#        2.82850499, 1.28187233, 1.14201102, 1.15832748, 1.60125649,
#        1.74823011, 1.98373095, 1.23124948, 1.05892261, 1.55653267,
#        1.63501901, 1.93156013, 0.99591599, 1.67614484, 1.87959849,
#        1.72919424, 4.50667338, 2.30035387, 3.22168974, 2.0107577 ,
#        1.72718606, 1.22622903, 2.49732278, 1.9674145 , 1.36023316,
#        1.52687019, 2.2434973 , 4.64377345, 3.73461217, 1.80475198,
#        1.7332106 , 1.97147269, 2.1823315 , 2.48862067, 2.61463391,
#        1.77370888, 2.02841294, 2.44941933, 1.15025292, 1.71220839,
#        1.50478022, 1.14669677, 1.58447983, 1.85248808, 1.96565734,
#        2.91289035, 6.72466544, 2.28399558, 1.42729797, 1.87236068,
#        1.85780138, 2.27943534, 1.76124143, 2.25328717, 2.58413469,
#        1.24585062, 1.57753488, 1.45880128, 1.52251914, 3.86966222,
#        1.28944484, 3.10906436, 1.37646594, 1.34517181, 1.40784374,
#        1.11728531, 1.780612  , 2.24458506, 1.39441404, 1.78688756,
#        3.13140535, 2.23584111, 2.79875884, 1.24961595, 1.09448411,
#        3.04932103, 1.85110745, 3.84309568, 1.0304734 , 1.36424951,
#        2.75315643, 1.57866448, 1.71070226, 1.75044747, 2.68316302,
#        2.80980382, 1.73454939, 3.04626692, 3.07940188, 1.1839736 ,
#        1.16376629, 1.2415414 , 1.60640245, 2.42042625, 1.41156724,
#        3.25469918, 3.32632424, 1.89909457, 2.38729129, 1.07297986,
#        0.80580836, 1.80512852, 1.39909979, 4.05353612, 1.93369382,
#        1.82123579, 2.51953826, 1.52113851, 1.77337418, 1.80127951,
#        1.63577207, 2.15555578, 1.73233202, 5.17577358, 1.42524796,
#        1.72701871, 4.54993291, 2.87352167, 2.75587584, 2.25002388,
#        1.69112251, 0.83965454])

# %% [markdown]
# ### Avaliando

# %%
print("\nExemplos de previsão:\n")

for i in range(5):
    print("Valor real: $", alvo_house_teste.iloc[i])
    print("Valor predito: $", pred[i])
    print("----")
# Out:
# Exemplos de previsão:
#
# Valor real: $ 0.477
# Valor predito: $ 1.1524284493722048
# ----
# Valor real: $ 0.458
# Valor predito: $ 1.5080853480810756
# ----
# Valor real: $ 5.00001
# Valor predito: $ 1.9050354310065865
# ----
# Valor real: $ 2.186
# Valor predito: $ 2.849507197663775
# ----
# Valor real: $ 2.78
# Valor predito: $ 2.007494405825787
# ----

# %% [markdown]
# Quão bem foi o modelo? Para isso vamos usar o MAE. O MAE é o erro absoluto médio. É a média dos erros.
#
# MAE = média(valor real−valor predito)

# %%
from sklearn.metrics import mean_absolute_error # importamos o MAE para poder usa-lo

erro = mean_absolute_error(alvo_house_teste, pred)
print("Erro médio absoluto ...............", erro)
print(f"Erro médio absoluto em dólares ... $ {erro*100000:.2f}")
# Out:
# Erro médio absoluto ............... 0.6469652639373658
# Erro médio absoluto em dólares ... $ 64696.53

# %% [markdown]
# #### Entendendo o resultado da avaliação
#
# Esse erro médio mostra que o modelo erra em média $60.000 por predição que ele faz

# %% [markdown]
# ## Visualizando a regressão

# %%
plt.title("Regressão Linear")
plt.scatter(colunas_house_teste, alvo_house_teste, color="blue", marker="o", label="Valor real") # scatter é o "gráfico de bolinhas". Dizemos a cor, o tipo de marcador e o rótulo (label)
plt.plot(colunas_house_teste, pred, color="red", marker="x", linestyle="-", label="Predição") # plot é o "gráfico de linha". Dizemos a cor, o marcador, tipo do tracejado e o rótulo (label)
plt.xlabel("MedInc")
plt.ylabel("House Value")
plt.legend()
plt.show()

# %% [markdown]
# ### Dicas
#
# - Para ver quais datasets temos disponiveis no sklearn, basta acessar esse link https://scikit-learn.org/stable/datasets.html

# %% [markdown]
# ### Experimente você mesmo!
#
# **1. Troque a feature e veja o impacto no erro:**
# ```python
# # Tente usar "HouseAge" ou "AveRooms" no lugar de "MedInc" e compare o MAE
# colunas_house = dataset_california_housing[["HouseAge"]]
# ```
#
# **2. Use duas features ao mesmo tempo:**
# ```python
# # O modelo melhora quando damos mais informações para ele?
# colunas_house = dataset_california_housing[["MedInc", "AveRooms"]]
# ```
#
# **3. Aumente o tamanho do conjunto de teste:**
# ```python
# # Troque test_size=0.01 por test_size=0.2 — as previsões tem melhores resultados?
# train_test_split(colunas_house, alvo_house, test_size=0.2)
# ```

# %%
colunas_house = dataset_california_housing[["HouseAge"]]

correlacao_pearson = colunas_house["HouseAge"].corr(alvo_house, method="pearson")

fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs[0].set_title(f"Correlação de Pearson: {correlacao_pearson:.5f}", fontsize=10, loc="left")
axs[0].scatter(colunas_house, alvo_house, alpha=0.5)
axs[0].set_xlabel("HouseAge (Idade média das casas)", fontsize=8)
axs[0].set_ylabel("MedHouseVal (Valor médio das casas)", fontsize=8)
axs[1].boxplot([colunas_house["HouseAge"], alvo_house], tick_labels=["HouseAge", "MedHouseVal"])

plt.tight_layout()
plt.show()

# %%
colunas_house_treino, colunas_house_teste, alvo_house_treino, alvo_house_teste = train_test_split(colunas_house, alvo_house, test_size=0.01, random_state=42) # divide em treino e teste. Teste só 1% do database

modelo_house = LinearRegression() # aqui estamos dizendo que queremos usar a Regressão Linear
modelo_house.fit(colunas_house_treino, alvo_house_treino) # a função fit é a que faz o treino, ou seja, momento que o modelo começa a aprender com os dados
pred = modelo_house.predict(colunas_house_teste) # com o modelo treinado, podemos predizer o valor das casas de teste

plt.title("Regressão Linear")
plt.scatter(colunas_house_teste, alvo_house_teste, color="blue", marker="o", label="Valor real") # scatter é o "gráfico de bolinhas". Dizemos a cor, o tipo de marcador e o rótulo (label)
plt.plot(colunas_house_teste, pred, color="red", marker="x", linestyle="-", label="Predição") # plot é o "gráfico de linha". Dizemos a cor, o marcador, tipo do tracejado e o rótulo (label)
plt.xlabel("HouseAge")
plt.ylabel("House Value")
plt.legend()
plt.show()

erro = mean_absolute_error(alvo_house_teste, pred)
print("Erro médio absoluto ...............", erro)
print(f"Erro médio absoluto em dólares ... $ {erro*100000:.2f}")
# Out:
# Erro médio absoluto ............... 0.8923012500695726
# Erro médio absoluto em dólares ... $ 89230.13

# %%
correlacao_pearson = dataset_california_housing.corr(method="pearson")

import seaborn as sns

plt.figure(figsize=(5,5))
ax = sns.heatmap(
    correlacao_pearson, 
    annot=True, 
    cmap='coolwarm', 
    fmt=".2f", 
    annot_kws={"size":7}
)
plt.xticks(fontsize=7)  
plt.yticks(fontsize=7)

colorbar = ax.collections[0].colorbar
colorbar.ax.tick_params(labelsize=7)

plt.show()

# %%
colunas_house = dataset_california_housing[["MedInc", "AveRooms"]]

colunas_house_treino, colunas_house_teste, alvo_house_treino, alvo_house_teste = train_test_split(colunas_house, alvo_house, test_size=0.01, random_state=42) # divide em treino e teste. Teste só 1% do database

modelo_house = LinearRegression() # aqui estamos dizendo que queremos usar a Regressão Linear
modelo_house.fit(colunas_house_treino, alvo_house_treino) # a função fit é a que faz o treino, ou seja, momento que o modelo começa a aprender com os dados
pred = modelo_house.predict(colunas_house_teste) # com o modelo treinado, podemos predizer o valor das casas de teste

erro = mean_absolute_error(alvo_house_teste, pred)
print("Erro médio absoluto ...............", erro)
print(f"Erro médio absoluto em dólares ... $ {erro*100000:.2f}")
# Out:
# Erro médio absoluto ............... 0.6384795285141714
# Erro médio absoluto em dólares ... $ 63847.95

# %%
colunas_house = dataset_california_housing[["MedInc", "AveRooms"]]

colunas_house_treino, colunas_house_teste, alvo_house_treino, alvo_house_teste = train_test_split(colunas_house, alvo_house, test_size=0.2, random_state=42) # divide em treino e teste. Teste só 20% do database

modelo_house = LinearRegression() # aqui estamos dizendo que queremos usar a Regressão Linear
modelo_house.fit(colunas_house_treino, alvo_house_treino) # a função fit é a que faz o treino, ou seja, momento que o modelo começa a aprender com os dados
pred = modelo_house.predict(colunas_house_teste) # com o modelo treinado, podemos predizer o valor das casas de teste

erro = mean_absolute_error(alvo_house_teste, pred)
print("Erro médio absoluto ...............", erro)
print(f"Erro médio absoluto em dólares ... $ {erro*100000:.2f}")
# Out:
# Erro médio absoluto ............... 0.624682807713972
# Erro médio absoluto em dólares ... $ 62468.28

# %% [markdown]
# ### Werner Denzin | Resultados:
#
#  * Experimento 1 : MedInc ; test size = 1% ; MAE = 0.6470 ; Erro = 64.7K
#  * Experimento 2 : HouseAge ; test size = 1% ; MAE = 0.8923 ; Erro = 89.2K
#  * Experimento 3 : MedInc + AveRooms ; test size = 1% ; MAE = 0.6385 ; Erro = 63.8K
#  * Experimento 4 : MedInc + AveRooms ; test size = 20% ; MAE = 0.6246 ; Erro = 62.4K
#
# Portanto, ao adicionarmos mais features e aumentando a partição de teste, conseguimos uma melhor performance de aprendizado, `< MAE`!<br>
# E observando a correlação de Pearson, as 3 features utilizadas nos experimentos são as com maiores correlações com Y, `MedHouseVal`

# %% [markdown]
# # 2️⃣ Regressão Logística
#
# Apesar do nome, a regressão logística é usada para **classificação**.
#
# Exemplo: prever se um tumor é **maligno ou benigno**.
#
# Vamos usar o dataset **Breast Cancer**.

# %%
# importando as bibliotecas necessarias
from sklearn.datasets import load_breast_cancer # dataset cancer de mama
from sklearn.linear_model import LogisticRegression # modelo de regressão logística
from sklearn.metrics import accuracy_score # métricas nova: acurácia

# %%
dataset_breast_cancer = load_breast_cancer(as_frame=True).frame # carrega o dataset e transforma em um dataset pandas

# %%
dataset_breast_cancer.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension      target
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
dataset_breast_cancer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %% [markdown]
# ### Explicação das colunas
#
# - **mean radius** -> raio médio do tumor
# - **mean texture** ->	variação média da textura
# - **mean perimeter** ->	perímetro médio do tumor
# - **mean area** ->	área média do tumor
# - **mean smoothness** ->	suavidade média da borda
# - **mean compactness** ->	densidade média da massa
# - **mean concavity** ->	profundidade média das concavidades
# - **target** -> câncer de mama (1) ou não (0)

# %%
# separar features e target. Daqui para frente chamaremos dessa maneira
features = dataset_breast_cancer.drop(columns=["target"]) # features: todas as colunas do dataset, menos a coluna target
target = dataset_breast_cancer["target"] # target: a coluna que vai dizer se é cancer ou não

# %%
# separar em treino e teste
features_treino, features_teste, target_treino, target_teste = train_test_split(features, target, test_size=0.1, random_state=42) # 10% do nosso dataset vai ser usado para teste e os outros 90% para treinar o modelo

# %%
modelo_breast_cancer = LogisticRegression(max_iter=10000) # criando o modelo de Regressão Logística
# Werner Denzin: precisei adicionar max_iter para solucionar este erro: "ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1)"

# %%
modelo_breast_cancer.fit(features_treino, target_treino) # treino usando a função fit
# Out:
# LogisticRegression(max_iter=10000)

# %%
pred = modelo_breast_cancer.predict(features_teste) # predição do set de teste usando a função predict

# %%
print("\nExemplos de previsão:\n")

for i in range(5):
    print("Valor real:", target_teste.iloc[i])
    print("Valor predito:", pred[i])
    print("-----")
# Out:
# Exemplos de previsão:
#
# Valor real: 1
# Valor predito: 1
# -----
# Valor real: 0
# Valor predito: 0
# -----
# Valor real: 0
# Valor predito: 0
# -----
# Valor real: 1
# Valor predito: 1
# -----
# Valor real: 1
# Valor predito: 1
# -----

# %%
# acurácia
accuracy = accuracy_score(target_teste, pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9824561403508771

# %% [markdown]
# ### Entendendo o resultado
#
# A acurácia de X% significa que o modelo acertou **X% dos diagnósticos**.
#
# Em outras palavras: uma acurácia de 94% siginifica que de cada 100 tumores analisados, ele errou apenas 6.
#
# Para um problema médico, isso parece ótimo, mas cuidado: acurácia sozinha pode enganar.
# Imagine um dataset onde 94% dos casos são benignos. Um modelo burro que sempre responde
# "benigno" teria 94% de acurácia sem aprender nada.
#
# Por isso, em problemas médicos costumamos usar métricas adicionais.

# %% [markdown]
# ## Comparando previsões

# %%
plt.figure(figsize=(7,4)) # figsize é o tamanho da figura

plt.scatter(range(len(target_teste)), target_teste,
            marker="o", color="blue", label="Valor real") # gráfico de pontos, marcador "bolinha", cor azul, para os valores reais do dataset

plt.scatter(range(len(pred)), pred,
            marker="x", color="red", label="Predição") # gráfico de pontos, marcador "em X", cor vermelha, para os valores que foram preditos pelo nosso modelo

plt.yticks([0,1], ["Maligno", "Benigno"])
plt.xlabel("Amostras do teste")
plt.ylabel("Classificação")
plt.title("Regressão Logística: Real vs Predito")

plt.legend()
plt.show()

# %% [markdown]
# ### Explicando o Resultado
#
# A regressão logística calcula a probabilidade de algo pertencer a uma classe.
#
# Se a probabilidade passar de 50%, o modelo escolhe aquela classe.
#
# Imagine um médico analisando um tumor.
# Ele não pensa "é benigno ou maligno" imediatamente.
#
# Ele pensa algo como:
#
# *“Parece benigno com 80% de chance.”*
#
# A regressão faz exatamente isso, mas usando matemática.

# %% [markdown]
# ### Experimente você mesmo!
#
# **1. Remova a coluna mais importante e veja a acurácia cair:**
# ```python
# # "mean radius" é uma das features mais relevantes. O que acontece sem ela?
# features = dataset_breast_cancer.drop(columns=["target", "mean radius"])
# ```
#
# **2. Use metade dos dados para teste:**
# ```python
# # O que acontece com a acurácia quando o modelo tem menos dados para treinar?
# train_test_split(features, target, test_size=0.5)
# ```

# %%
correl_target = dataset_breast_cancer.corr(method="pearson")["target"].drop("target")
correl_df = correl_target.to_frame(name="corr")
correl_df["abs_corr"] = correl_df["corr"].abs()
correl_df_sorted = correl_df.sort_values("abs_corr", ascending=False)
correl_df_sorted.head(10)
# Out:
#                           corr  abs_corr
# worst concave points -0.793566  0.793566
# worst perimeter      -0.782914  0.782914
# mean concave points  -0.776614  0.776614
# worst radius         -0.776454  0.776454
# mean perimeter       -0.742636  0.742636
# worst area           -0.733825  0.733825
# mean radius          -0.730029  0.730029
# mean area            -0.708984  0.708984
# mean concavity       -0.696360  0.696360
# worst concavity      -0.659610  0.659610

# %%
features = dataset_breast_cancer.drop(columns=["target", "mean radius"])
features_treino, features_teste, target_treino, target_teste = train_test_split(features, target, test_size=0.1, random_state=42) # 10% do nosso dataset vai ser usado para teste e os outros 90% para treinar o modelo
modelo_breast_cancer = LogisticRegression(max_iter=10000)
modelo_breast_cancer.fit(features_treino, target_treino)
pred = modelo_breast_cancer.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 2 - Accuracy:", accuracy)

features_treino, features_teste, target_treino, target_teste = train_test_split(features, target, test_size=0.5, random_state=42) # 50% do nosso dataset vai ser usado para teste e os outros 50% para treinar o modelo
modelo_breast_cancer = LogisticRegression(max_iter=10000)
modelo_breast_cancer.fit(features_treino, target_treino)
pred = modelo_breast_cancer.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 3 - Accuracy:", accuracy)
# Out:
# Experimento 2 - Accuracy: 0.9824561403508771
# Experimento 3 - Accuracy: 0.9578947368421052

# %% [markdown]
# ### Werner Denzin | Resultados:
#
#  * Experimento 1 : todas as features ; test size = 10% ; accuracy = 98.25%
#  * Experimento 2 : removida, `mean radius` ; test size = 10% ; accuracy = 98.25%
#  * Experimento 3 : removida, `mean radius` ; test size = 50% ; accuracy = 97.79%
#
# Portanto, pelos testes, a remoção da feature não proporcionou queda da performance. Provavelmente, porque as demais features já carregam a "informação" contida na feature `mean radius`.<br>
# Porém, ao reduzir em 50% a quantidade de registros para treinamento, foi possível observar queda da acurácia, pois o modelo teve menos registros para aprendizado.

# %% [markdown]
# # 3️⃣ Árvore de Decisão
#
# Árvores de decisão funcionam como **fluxogramas de decisão**.
#
# Vamos usar novamente o dataset **Titanic**.

# %%
from sklearn.tree import DecisionTreeClassifier # importa a biblioteca de Árvore de Decisão

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
dataset_titanic = pd.read_csv(url)
dataset_titanic = dataset_titanic[["Pclass","Sex","Age","Fare","Survived"]] # escolhe quais colunas do Titanic vai usar

# %%
dataset_titanic.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
print("Valores faltantes por coluna:\n")
print(dataset_titanic.isnull().sum())
# Out:
# Valores faltantes por coluna:
#
# Pclass        0
# Sex           0
# Age         177
# Fare          0
# Survived      0
# dtype: int64

# %%
dataset_titanic["Sex"] = dataset_titanic["Sex"].map({"male":0,"female":1}) # aqui deixamos o valor 0 como masculino e 1 como feminino. A árvore de decisão não entende "palavras" aqui

# %%
dataset_titanic = dataset_titanic.dropna() # remove todas as linhas que estão vazias, ou seja, todas as linhas que tem alguém sem idade

# %%
dataset_titanic.head()
# Out:
#    Pclass  Sex   Age     Fare  Survived
# 0       3    0  22.0   7.2500         0
# 1       1    1  38.0  71.2833         1
# 2       3    1  26.0   7.9250         1
# 3       1    1  35.0  53.1000         1
# 4       3    0  35.0   8.0500         0

# %%
features = dataset_titanic[["Pclass","Sex","Age","Fare"]] # define quais são nossas features
target = dataset_titanic["Survived"] # define qual é nosso target

# %%
features_treino, features_teste, target_treino, target_teste = train_test_split(features, target, test_size=0.2, random_state=42) # divide em treino (80%) e teste (20%)

# %%
modelo_titanic = DecisionTreeClassifier(max_depth=3) # aqui diz que usaremos uma árvore de classificação com profundidade 3

# %%
modelo_titanic.fit(features_treino, target_treino) # treina o modelo
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
pred = modelo_titanic.predict(features_teste) # faz as predições

# %%
print("\nExemplos de previsão:\n")

for i in range(5):
    print("Valor real:", target_teste.iloc[i])
    print("Valor predito:", pred[i])
    print("-----")
# Out:
# Exemplos de previsão:
#
# Valor real: 0
# Valor predito: 0
# -----
# Valor real: 1
# Valor predito: 1
# -----
# Valor real: 1
# Valor predito: 1
# -----
# Valor real: 1
# Valor predito: 1
# -----
# Valor real: 0
# Valor predito: 0
# -----

# %%
accuracy = accuracy_score(target_teste, pred)
print("\nAccuracy:", accuracy)
# Out:
# Accuracy: 0.7482517482517482

# %% [markdown]
# ## Visualizando previsões

# %%
from sklearn import tree
plt.figure(figsize=(14,8))

tree.plot_tree(
    modelo_titanic,
    feature_names=["Pclass","Sex","Age","Fare"],
    class_names=["Não sobreviveu","Sobreviveu"],
    filled=True
)

plt.title("Árvore de Decisão - Titanic")
plt.show()

# %%
plt.figure(figsize=(7,4))

plt.scatter(features_teste["Age"], target_teste,
            color="blue", marker="o", label="Valor real")

plt.scatter(features_teste["Age"], pred,
            color="red", marker="x", label="Predição")

plt.xlabel("Age")
plt.ylabel("Survived")
plt.yticks([0,1], ["Não", "Sim"])
plt.title("Árvore de Decisão - Titanic")

plt.legend()
plt.show()

# %% [markdown]
# ### Experimente você mesmo!
#
# **1. Mude a profundidade da árvore:**
# ```python
# # Tente max_depth=1, max_depth=5 e max_depth=10 — o que acontece com a acurácia?
# # Dica: uma árvore muito profunda "decora" os dados de treino e vai mal no teste
# modelo_titanic = DecisionTreeClassifier(max_depth=1)
# ```
#
# **2. Remova a coluna "Sex" e veja o impacto:**
# ```python
# # Sexo foi um critério real de embarque nos botes salva-vidas.
# # O modelo piora muito sem essa informação?
# features = dataset_titanic[["Pclass", "Age", "Fare"]]
# ```
#
# **3. Plote a árvore com profundidade 1 — fica pequena e fácil de ler:**
# ```python
# modelo_titanic_simples = DecisionTreeClassifier(max_depth=1)
# modelo_titanic_simples.fit(features_treino, target_treino)
#
# tree.plot_tree(
#     modelo_titanic_simples,
#     feature_names=["Pclass", "Sex", "Age", "Fare"],
#     class_names=["Não sobreviveu", "Sobreviveu"],
#     filled=True
# )
# plt.show()
# ```

# %%
modelo_titanic = DecisionTreeClassifier(max_depth=1)
modelo_titanic.fit(features_treino, target_treino)
pred = modelo_titanic.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 2 - Accuracy:", accuracy)

modelo_titanic = DecisionTreeClassifier(max_depth=5)
modelo_titanic.fit(features_treino, target_treino)
pred = modelo_titanic.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 3 - Accuracy:", accuracy)

modelo_titanic = DecisionTreeClassifier(max_depth=10)
modelo_titanic.fit(features_treino, target_treino)
pred = modelo_titanic.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 4 - Accuracy:", accuracy)

features = dataset_titanic[["Pclass", "Age", "Fare"]]
features_treino, features_teste, target_treino, target_teste = train_test_split(features, target, test_size=0.2, random_state=42) # divide em treino (80%) e teste (20%)
modelo_titanic = DecisionTreeClassifier(max_depth=1)
modelo_titanic.fit(features_treino, target_treino)
pred = modelo_titanic.predict(features_teste)
accuracy = accuracy_score(target_teste, pred)
print("Experimento 5 - Accuracy:", accuracy)

tree.plot_tree(
    modelo_titanic,
    feature_names=["Pclass", "Sex", "Age", "Fare"],
    class_names=["Não sobreviveu", "Sobreviveu"],
    filled=True
)
plt.show()
# Out:
# Experimento 2 - Accuracy: 0.7342657342657343
# Experimento 3 - Accuracy: 0.7202797202797203
# Experimento 4 - Accuracy: 0.7762237762237763
# Experimento 5 - Accuracy: 0.6713286713286714

# %% [markdown]
# ### Werner Denzin | Resultados:
#
#  * Experimento 1 : max_depth = 3 ; todas as features ; accuracy = 74.1%
#  * Experimento 2 : max_depth = 1 ; todas as features ; accuracy = 73.4%
#  * Experimento 3 : max_depth = 5 ; todas as features ; accuracy = 72.0%
#  * Experimento 4 : max_depth = 10 ; todas as features ; accuracy = 77.6%
#  * Experimento 5 : max_depth = 1 ; removida, `Sex` ; accuracy = 67.1%
#
# Portanto, avaliando a performance de `max_depth` no geral, quanto mais profunda a árvore, melhor sua performance!<br>
# Porém, com o risco de overfitting para árvores mais profundas, e underfitting para árvores muito rasas.<br>
# E ao remover a feature, `Sex`, observamos uma queda de 10% (entre experimentos 4 e 5): evidenciando a importância da feature para determinação de Y

# %% [markdown]
# # 4️⃣ K-Means (Clustering)
#
# Diferente dos outros modelos, o **K-Means não usa rótulos**.
#
# Ele tenta **descobrir grupos automaticamente** nos dados.

# %%
from sklearn.datasets import load_iris # caregga o dataset IRIS
from sklearn.cluster import KMeans # carrega o modelo KMeans

dataset_iris = load_iris(as_frame=True).frame # transforma o dataset IRIS em um dataset pandas

# %%
dataset_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Explicação das colunas
#
# - **sepal length (cm):**	comprimento da sépala da flor
# - **sepal width (cm):**	largura da sépala da flor
# - **petal length (cm):**	comprimento da pétala
# - **petal width (cm)**	largura da pétala
# - **target:**	espécie da flor (0 → Setosa; 1 → Versicolor; 2 → Virginica)

# %%
features = dataset_iris.drop(columns=["target"]) # nossas features: todas as colunas, exceto o target, ou seja, sepal length, sepal width, petal length, petal width
target = dataset_iris["target"] # coluna target aqui é a espécie da flor

# %%
modelo_kmeans = KMeans(n_clusters=3, random_state=42) # estamos dizendo que queremos usar o K Means e formar 3 grupos

# %%
# treino
modelo_kmeans.fit(features)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# prever clusters
pred = modelo_kmeans.predict(features)

# %%
print("\nExemplos de clusterização:\n")

for i in range(5):
    print("Classe real:", target.iloc[i])
    print("Cluster encontrado:", pred[i])
    print("-----")
# Out:
# Exemplos de clusterização:
#
# Classe real: 0
# Cluster encontrado: 1
# -----
# Classe real: 0
# Cluster encontrado: 1
# -----
# Classe real: 0
# Cluster encontrado: 1
# -----
# Classe real: 0
# Cluster encontrado: 1
# -----
# Classe real: 0
# Cluster encontrado: 1
# -----

# %%
plt.figure(figsize=(6,5))

plt.scatter(
    features["petal length (cm)"],
    features["petal width (cm)"],
    c=pred,
    cmap="viridis",
    marker="o"
)

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("K-Means Clustering (Iris)")

plt.show()

# %% [markdown]
# ## Visualizando os clusters

# %%
centroids = modelo_kmeans.cluster_centers_

plt.figure(figsize=(6,5))

plt.scatter(
    features["petal length (cm)"],
    features["petal width (cm)"],
    c=pred,
    cmap="viridis",
    marker="o"
)

plt.scatter(
    centroids[:,2],
    centroids[:,3],
    color="red",
    marker="X",
    s=200,
    label="Centroids"
)

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("K-Means Clustering com Centróides")

plt.legend()
plt.show()

# %% [markdown]
# ### 🧪 Experimente você mesmo!
#
# **1. Mude o número de clusters:**
# ```python
# # O que acontece quando pedimos 2 grupos? E 5 grupos?
# # O modelo vai tentar se virar de qualquer jeito — mas vai fazer sentido?
# modelo_kmeans = KMeans(n_clusters=2)
# ```

# %%
target.value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
from sklearn.metrics import adjusted_rand_score, silhouette_score                        

print("Experimento 1 - adjusted_rand_score:", adjusted_rand_score(target, pred))
print("Experimento 1 - silhouette_score:", silhouette_score(features, pred))

modelo_kmeans = KMeans(n_clusters=2, random_state=42) 
modelo_kmeans.fit(features)
pred = modelo_kmeans.predict(features)
print("Experimento 2 - adjusted_rand_score:", adjusted_rand_score(target, pred))
print("Experimento 2 - silhouette_score:", silhouette_score(features, pred))

modelo_kmeans = KMeans(n_clusters=5, random_state=42)
modelo_kmeans.fit(features)
pred = modelo_kmeans.predict(features)
print("Experimento 3 - adjusted_rand_score:", adjusted_rand_score(target, pred))
print("Experimento 3 - silhouette_score:", silhouette_score(features, pred))

modelo_kmeans = KMeans(n_clusters=10, random_state=42)
modelo_kmeans.fit(features)
pred = modelo_kmeans.predict(features)
print("Experimento 4 - adjusted_rand_score:", adjusted_rand_score(target, pred))
print("Experimento 4 - silhouette_score:", silhouette_score(features, pred))

centroids = modelo_kmeans.cluster_centers_

plt.figure(figsize=(6,5))

plt.scatter(
    features["petal length (cm)"],
    features["petal width (cm)"],
    c=pred,
    cmap="viridis",
    marker="o"
)

plt.scatter(
    centroids[:,2],
    centroids[:,3],
    color="red",
    marker="X",
    s=200,
    label="Centroids"
)

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.title("K-Means Clustering com Centróides")

plt.legend()
plt.show()
# Out:
# Experimento 1 - adjusted_rand_score: 0.7163421126838476
# Experimento 1 - silhouette_score: 0.551191604619592
# Experimento 2 - adjusted_rand_score: 0.5399218294207123
# Experimento 2 - silhouette_score: 0.6810461692117462
# Experimento 3 - adjusted_rand_score: 0.6154838709677419
# Experimento 3 - silhouette_score: 0.4930804067193521
# Experimento 4 - adjusted_rand_score: 0.4023947537912056
# Experimento 4 - silhouette_score: 0.3014143745325133

# %% [markdown]
# ### Werner Denzin | Resultados:
#
#  * Experimento 1 : n_clusters = 3 ; adjusted_rand_score = 0.71 ; silhouette_score = 0.55
#  * Experimento 2 : n_clusters = 2 ; adjusted_rand_score = 0.53 ; silhouette_score = 0.68
#  * Experimento 3 : n_clusters = 5 ; adjusted_rand_score = 0.61 ; silhouette_score = 0.49
#  * Experimento 4 : n_clusters = 10 ; adjusted_rand_score = 0.40 ; silhouette_score = 0.30
#
# Portanto, quanto mais próximo `n_clusters` à quantidade de classes, maior sua aderência às classes target. Vide `adjusted_rand_score` e  `n_clusters` = 3.<br>
# Por outro lado, `n_clusters` = 2 foi o que apresentou melhor separação dos clusters (`silhouette_score`). <br>
# O aumentar da quantidade de clusters, pode fragmentar demais as classes target reduzindo a performance do modelo, vide os scores para `n_clusters` = 5 e 10

# %% [markdown]
# # Conclusão e próximos passos
#
# Treinamos quatro modelos:
# - **Regressão Linear**
# - **Regressão Logística**
# - **Árvore de Decisão**
# - **K-Means**
#
# Todos seguem o mesmo padrão:
#
# model = Modelo()
# model.fit(X, y)
# model.predict(X)
#
# # Incluir abaixo
# Exercício com Redes Neurais (MLP ou CNN):
# - **Construir modelos de rede neurais para os problemas acima**
#
# Exercícios desafios (avançados):
#
# -	**Incluir ajustes de hiperparâmetros (com validação cruzada) para cada rede neural**
# -	**Incluir métricas e visualizações adicionais para cada modelo criado**
# -	**Construir análise comparativa entre os modelos**
#
# # Importante
# As atividades práticas não são avaliativas, mas devem ser entregues da seguinte forma para obtenção de feedback pelo monitor da disciplina:
# - **Entregar arquivo ipynb ou link para notebook compartilhado para leitura**
# - **O notebook deve incluir os resultados da execução, bem como explicações sobre os passos realizados**
